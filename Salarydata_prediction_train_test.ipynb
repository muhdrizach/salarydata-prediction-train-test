# %%
import pandas as pd
df=pd.read_csv("Salary_Data_1.csv")

# %%
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
mylist=[1,2,3,4]
mypdseries=pd.Series(mylist)
print(mypdseries)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
mylist=[1,2,3,4]
mypdseries=pd.Series(mylist)
print(mypdseries)
mypdseries=pd.Series(mylist, index=["a","b","c","d"])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
print(pd.options.display.max_rows)
pd.options.display.max_rows=999
print(pd.options.display.max_rows)
# Out:
# 60
# 999

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.show()

# %%
x=df.iloc[:,[0]].values
y=df.iloc[:,1].values

print(x)
print(y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.shape
# Out:
# (21, 1)

# %%
x_test.shape
# Out:
# (9, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([ 40817.78327049, 123188.08258899,  65154.46261459,  63282.41035735,
#        115699.87356004, 108211.66453108, 116635.89968866,  64218.43648597,
#         76386.77615802])

# %%
y_test
# Out:
# array([ 37731., 122391.,  57081.,  63218., 116969., 109431., 112635.,
#         55794.,  83088.])

# %%
df1=pd.DataFrame({'Actual Salary':y_test,'Predicted Salary':y_pred,'Differences in %':((y_pred-y_test)/(y_test)*100)})
df1
# Out:
#    Actual Salary  Predicted Salary  Differences in %
# 0        37731.0      40817.783270          8.181027
# 1       122391.0     123188.082589          0.651259
# 2        57081.0      65154.462615         14.143870
# 3        63218.0      63282.410357          0.101886
# 4       116969.0     115699.873560         -1.085011
# 5       109431.0     108211.664531         -1.114251
# 6       112635.0     116635.899689          3.552093
# 7        55794.0      64218.436486         15.099180
# 8        83088.0      76386.776158         -8.065213

# %%
plt.scatter(x_train,y_train,c='r')
plt.plot(x_train,model.predict(x_train))

# %%
df1.to_csv('Predicted_Values.csv')

# %%
pd.read_csv('Predicted_Values.csv')
# Out:
#    Unnamed: 0  Actual Salary  Predicted Salary  Differences in %
# 0           0        37731.0      40817.783270          8.181027
# 1           1       122391.0     123188.082589          0.651259
# 2           2        57081.0      65154.462615         14.143870
# 3           3        63218.0      63282.410357          0.101886
# 4           4       116969.0     115699.873560         -1.085011
# 5           5       109431.0     108211.664531         -1.114251
# 6           6       112635.0     116635.899689          3.552093
# 7           7        55794.0      64218.436486         15.099180
# 8           8        83088.0      76386.776158         -8.065213

# %%
from sklearn.metrics import accuracy_score

# %%
model.score(x_test,y_test)*100
# Out:
# 97.4099340721351
